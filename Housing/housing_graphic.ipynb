# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('housing.csv')
columns = df[['housing_median_age','total_rooms','total_rooms' ]]
plt.plot(df['housing_median_age'],color='blue')
plt.plot(df['total_rooms'], color='green')  # You can use different colors for each line
plt.plot(df['population'], color ='yellow')
plt.plot()
plt.show()
